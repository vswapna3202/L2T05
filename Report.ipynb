# %%
# Import pandas
import pandas as pd

# %%
# Create a DataFrame with balance.txt
df = pd.read_csv('balance.txt',sep = ' ')

# %% [markdown]
# Write the code needed to produce a report that provides the following information:
# * Compare the average income based on ethnicity.
# * On average, do married or single people have a higher balance?
# * What is the highest income in our dataset?
# * What is the lowest income in our dataset?
# * How many cards do we have recorded in our dataset? (Hint: use `sum()`)
# * How many females do we have information for vs how many males? (Hint: use `count()`For a list of all methods for computation of descriptive stats, explore the [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html#computations-descriptive-stats)).

# %%
# Compare the average income based on ethnicity
print(df.groupby('Ethnicity')['Income'].mean())
# Out:
# Ethnicity
# African American    47.682101
# Asian               44.187833
# Caucasian           44.521945
# Name: Income, dtype: float64

# %%
# On average, do married or single people have better balance
married_avg_balance = df[df['Married'] == 'Yes']['Balance'].mean()
single_avg_balance = df[df['Married'] == 'No']['Balance'].mean()
if married_avg_balance > single_avg_balance:
    print("Married individuals have better balance")
else:
    print("Single individuals have better balance")
# Out:
# Single individuals have better balance

# %%
# What is the highest income in our dataset?
print(f"Highest Income in Dataset {df['Income'].max()}")
# Out:
# Highest Income in Dataset 186.634

# %%
# What is the lowest income in our dataset?
print(f"Lowest Income in Dataset {df['Income'].min()}")
# Out:
# Lowest Income in Dataset 10.354

# %%
# How many cards do we have recorded in our dataset
print(f"Number of Cards in Dataset {df['Cards'].sum()}")
# Out:
# Number of Cards in Dataset 1183

# %%
# How many females do we have information for vs for how many males?
print(f"Number of Females in Dataset {len(df[df['Gender'] == 'Female'])} "
 f"vs Number of Males in Dataset {len(df[df['Gender'] == 'Male'])}")
# Out:
# Number of Females in Dataset 207 vs Number of Males in Dataset 193
